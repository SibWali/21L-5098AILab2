# %%
import matplotlib.pyplot as plt
Question1

#group_A = [12, 15, 14, 13, 16, 18, 19, 15, 14, 20, 17, 14, 15, 40, 45, 50, 62]
#group_B = [12, 17, 15, 13, 19, 20, 21, 18, 17, 16, 15, 14, 16, 15]

#fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10))

# Plot Group A
#ax1.boxplot(group_A, vert=True)
#ax1.set_title('Group A Box Plot')
#ax1.set_ylabel('Measurement Values')

# Plot Group B
#ax2.boxplot(group_B, vert=True)
#ax2.set_title('Group B Box Plot')
#ax2.set_ylabel('Measurement Values')

# title and display
#plt.suptitle('Comparison of Group A and Group B')
#plt.tight_layout()
#plt.show()

#-------------------------------------------------------------------------
#Question2

#import numpy as np
#import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D

# Read genome.txt
#with open('genome.txt', 'r') as file:
 #   genome_sequence = file.read().strip()

#genome_list = list(genome_sequence)
#genome_length = len(genome_list)

#helix coordinates
#t = np.linspace(0, 4 * np.pi, genome_length)
#x = np.cos(t)
#y = np.sin(t)
#z = np.linspace(0, 5, genome_length)
#coordinates = np.column_stack((x, y, z))

# Assign colors 
#color_map = {'A': 'red', 'T': 'green', 'C': 'blue', 'G': 'yellow'}
#colors = [color_map.get(nucleotide, 'gray') for nucleotide in genome_list]


#fig = plt.figure(figsize=(10, 6))
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter(x, y, z, c=colors, s=10)
#ax.set_title('3D Helix Structure of Genome Sequence')
#plt.show()
#------------------------------------------------

#Question3

#import matplotlib.pyplot as plt
#import numpy as np


#img = plt.imread('/content/cardmethod.png')
#img_array = np.array(img)

# Plot original image
#plt.figure(figsize=(15, 10))

#plt.subplot(2, 2, 1)
#plt.imshow(img_array)
#plt.title('Original Image')

# Rotate image
#rotated_img = np.rot90(img_array)
#plt.subplot(2, 2, 2)
#plt.imshow(rotated_img)
#plt.title('Rotated 90°')

# Flip image
#flipped_img = np.fliplr(img_array)
#plt.subplot(2, 2, 3)
#plt.imshow(flipped_img)
#plt.title('Flipped Horizontally')


#gray_img = np.dot(img_array[..., :3], [0.299, 0.587, 0.114])
#plt.subplot(2, 2, 4)
#plt.imshow(gray_img, cmap='gray')
#plt.title('Grayscale Image')

#plt.tight_layout()
#plt.show()

#-------------------------------------------------------

#Question 4

#import numpy as np
#import matplotlib.pyplot as plt
#from sklearn.datasets import load_iris


#iris = load_iris()
#X = np.array(iris.data)  # Features
#Y = np.array(iris.target)  # Target

# Calculate statistics
#print("Mean:", np.mean(X, axis=0))
#print("Median:", np.median(X, axis=0))
#print("Std Dev:", np.std(X, axis=0))
#print("Min:", np.min(X, axis=0))
#print("Max:", np.max(X, axis=0))

# Extract sepal length and width
#sepal_features = X[:, [0, 1]]

#Visualizations
#plt.figure(figsize=(15, 5))

#Scatter plot
#plt.subplot(1, 3, 1)
#plt.scatter(X[:, 0], X[:, 1], c=Y)
#plt.xlabel('Sepal Length')
#plt.ylabel('Sepal Width')
#plt.title('Sepal Length vs Width')

# Histogram plot
#plt.subplot(1, 3, 2)
#plt.hist(X[:, 0], bins=20)
#plt.xlabel('Sepal Length')
#plt.title('Sepal Length Distribution')

# Line plot 
#sorted_indices = np.argsort(X[:, 2])
#plt.subplot(1, 3, 3)
#plt.plot(X[sorted_indices, 2], X[sorted_indices, 3])
#plt.xlabel('Petal Length')
#plt.ylabel('Petal Width')
#plt.title('Petal Length vs Width')

#plt.tight_layout()
#plt.show()

#----------------------------------------------------------------------------
